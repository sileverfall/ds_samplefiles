# %%
import numpy as np
import numpy.random as random
import scipy as sp
import pandas as pd
from pandas import Series, DataFrame

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
# %matplotlib inline

# %%
# %precision 3
# Out:
# '%.3f'

# %% [markdown]
# ## 長條圖

# %%
x = [1, 2, 3]
y = [10, 1, 4]

# 指定圖型大小
plt.figure(figsize = (10, 6))

plt.bar(x, y, align='center', width = 0.5)

#設定標籤
plt.xticks(x, ['A Class', 'B Class', 'C Class'])
plt.xlabel('Class')
plt.ylabel('Score')

#顯示隔線
plt.grid(True)

# %% [markdown]
# ## 橫向長條圖

# %%
x = [1, 2, 3]
y = [10, 1, 4]

# 指定圖型大小
plt.figure(figsize = (10, 6))

plt.barh(x, y, align='center')

#設定標籤
plt.yticks(x, ['A Class', 'B Class', 'C Class'])
plt.ylabel('Class')
plt.xlabel('Score')

#顯示隔線
plt.grid(True)

# %% [markdown]
# ## 多個圖形

# %%
y1 = np.array([30, 10, 40])
y2 = np.array([10, 50, 90])

# X軸
x = np.arange(len(y1))

# 圖形寬度
w = 0.4

# 圖型大小
plt.figure(figsize = (10, 6))

# 描繪圖形，對於y2右移一個寬度來描繪
plt.bar(x, y1, color = 'blue', width = w, label = 'Math first', align = 'center')
plt.bar(x + w, y2, color='green', width = w, label = 'Math final', align = 'center')

# 配置圖例
plt.legend(loc = 'best')

plt.xticks(x + w / 2, ['Class A', 'Class B', 'Class C'])
plt.grid(True)

# %% [markdown]
# ## 堆疊長條圖

# %%
height1 = np.array([100, 200, 300, 400, 500])
height2 = np.array([1000, 800, 600, 400, 200])

# X軸
x = np.array([1, 2, 3, 4, 5]) 

# 指定圖型大小
plt.figure(figsize = (10, 6))

# 圖形描繪
p1 = plt.bar(x, height1, color = 'blue')
p2 = plt.bar(x, height2, bottom = height1, color='lightblue')

# 顯示圖例
plt.legend((p1[0], p2[0]), ('Class 1', 'Class 2'))

# %% [markdown]
# ## 圓餅圖

# %%
labels = ['Frogs', 'Hogs', 'Dogs', 'Logs']
sizes = [15, 30, 45, 10]
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']
explode = (0, 0.1, 0, 0) 

plt.figure(figsize = (15, 6))


plt.pie(sizes, explode = explode, labels = labels, colors = colors,
        autopct = '%1.1f%%', shadow = True, startangle = 90)


plt.axis('equal')
# Out:
# (-1.2142507666786346,
#  1.134711077927507,
#  -1.1258468317413044,
#  1.101230806657754)

# %% [markdown]
# ## 泡泡圖

# %%
N = 25


x = np.random.rand(N)
y = np.random.rand(N)


colors = np.random.rand(N)


area = 10 * np.pi * (15 * np.random.rand(N)) ** 2


plt.figure(figsize = (15, 6))


plt.scatter(x, y, s = area, c = colors, alpha = 0.5)
plt.grid(True)

# %% [markdown]
# ## 金融資料視覺化

# %%
# 指定日期
idx = pd.date_range('2015/01/01', '2015/12/31 23:59', freq='T')

# 產生亂數
dn = np.random.randint(2, size = len(idx)) * 2 - 1

# 隨機漫步
# np.cumprod計算積之累積
rnd_walk = np.cumprod(np.exp(dn * 0.0002)) * 100

# resample('B')將資料依照營業日單位重新取樣
df = pd.Series(rnd_walk, index=idx).resample('B').ohlc()

# %%
df.plot(figsize = (15,6), legend = 'best', grid = True)
# Out:
# <AxesSubplot:>

# %%
## Plotly
from plotly.offline import init_notebook_mode, iplot
from plotly import figure_factory as FF

# Jupyter notebook用設定
init_notebook_mode(connected=True) 

# K現判定
fig = FF.create_candlestick(df.open, df.high, df.low, df.close, dates = df.index)
iplot(fig)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="11295453-b699-4a21-9ff4-4353f14f5f85" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("11295453-b699-4a21-9ff4-4353f14f5f85")) {                    Plotly.newPlot(                        "11295453-b699-4a21-9ff4-4353f14f5f85",                        [{"boxpoints":false,"fillcolor":"#3D9970","line":{"color":"#3D9970"},"name":"Increasing","showlegend":false,"whiskerwidth":0,"x":["2015-01-01T00:00:00","2015-01-01T00:00:00","2015-01-01T00:00:00","2015-01-01T00:00:00","2015-01-01T00:00:00","2015-01-01T00