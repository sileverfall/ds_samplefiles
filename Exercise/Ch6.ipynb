# %%
import numpy as np
import numpy.random as random
import scipy as sp
import pandas as pd
from pandas import Series, DataFrame

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
# %matplotlib inline

# %%
# %precision 3
# Out:
# '%.3f'

# %% [markdown]
# ## 資料索引

# %%
hier_df= DataFrame(
    np.arange(9).reshape((3,3)),
    index = [
        ['a','a','b'],
        [1,2,2]
    ], 
    columns = [
        ['Osaka','Tokyo','Osaka'],
        ['Blue','Red','Red']
    ]
)
hier_df
# Out:
#     Osaka Tokyo Osaka
#      Blue   Red   Red
# a 1     0     1     2
#   2     3     4     5
# b 2     6     7     8

# %%
hier_df.index.names =['key1','key2']
hier_df.columns.names =['city','color']
hier_df
# Out:
# city      Osaka Tokyo Osaka
# color      Blue   Red   Red
# key1 key2
# a    1        0     1     2
#      2        3     4     5
# b    2        6     7     8

# %%
# 過濾
hier_df['Osaka']
# Out:
# color      Blue  Red
# key1 key2
# a    1        0    2
#      2        3    5
# b    2        6    8

# %%
# 總和
hier_df.sum(level = 'key2', axis = 0)
# Out:
# city  Osaka Tokyo Osaka
# color  Blue   Red   Red
# key2
# 1         0     1     2
# 2         9    11    13

# %%
hier_df.sum(level = 'color', axis = 1)
# Out:
# color      Blue  Red
# key1 key2
# a    1        0    3
#      2        3    9
# b    2        6   15

# %%
# 刪除
hier_df.drop(['b'])
# Out:
# city      Osaka Tokyo Osaka
# color      Blue   Red   Red
# key1 key2
# a    1        0     1     2
#      2        3     4     5

# %%
#6-1
hier_data_frame1 = DataFrame(
    np.arange(12).reshape((3,4)),
    index = [['c','d','d'],[1,2,1]],
    columns = [
        ['Kyoto','Nagoya','Hokkaido','Kyoto'],
        ['Yellow','Yellow','Red','Blue']
    ]
)

hier_data_frame1.index.names = ['key1','key2']
hier_data_frame1.columns.names = ['city','color']
hier_data_frame1
# Out:
# city       Kyoto Nagoya Hokkaido Kyoto
# color     Yellow Yellow      Red  Blue
# key1 key2
# c    1         0      1        2     3
# d    2         4      5        6     7
#      1         8      9       10    11

# %%
hier_data_frame1['Kyoto']
# Out:
# color      Yellow  Blue
# key1 key2
# c    1          0     3
# d    2          4     7
#      1          8    11

# %%
#6-2
hier_data_frame1.sum(level = 'city', axis = 1)
# Out:
# city       Kyoto  Nagoya  Hokkaido
# key1 key2
# c    1         3       1         2
# d    2        11       5         6
#      1        19       9        10

# %%
#6-3
hier_data_frame1.sum(level = 'key2', axis = 0)
# Out:
# city   Kyoto Nagoya Hokkaido Kyoto
# color Yellow Yellow      Red  Blue
# key2
# 1          8     10       12    14
# 2          4      5        6     7

# %% [markdown]
# ## 資料結合

# %%
data1 = {
    'id': ['100', '101', '102', '103', '104', '106', '108', '110', '111',' 113'],
    'city': ['Tokyo', 'Osaka', 'Kyoto', 'Hokkaido', 'Tokyo', 'Tokyo', 'Osaka', 'Kyoto', 'Hokkaido', 'Tokyo'],
    'birth_year': [1990, 1989, 1992, 1997, 1982, 1991, 1988, 1990, 1995, 1981],
    'name': ['Hiroshi', 'Akiko', 'Yuki', 'Satoru', 'Steeve', 'Mituru', 'Aoi', 'Tarou', 'Suguru','Mitsuo']
}
df1 = DataFrame(data1)
df1
# Out:
#      id      city  birth_year     name
# 0   100     Tokyo        1990  Hiroshi
# 1   101     Osaka        1989    Akiko
# 2   102     Kyoto        1992     Yuki
# 3   103  Hokkaido        1997   Satoru
# 4   104     Tokyo        1982   Steeve
# 5   106     Tokyo        1991   Mituru
# 6   108     Osaka        1988      Aoi
# 7   110     Kyoto        1990    Tarou
# 8   111  Hokkaido        1995   Suguru
# 9   113     Tokyo        1981   Mitsuo

# %%
data2 = {
    'id': ['100', '101', '102', '105', '107'],
    'math': [50, 43, 33, 76, 98],
    'english': [90, 30, 20, 50, 30],
    'sex': ['M','F','F','M','M'], 
    'index_num': [0, 1, 2, 3, 4]
}
df2 = DataFrame(data2)
df2
# Out:
#     id  math  english sex  index_num
# 0  100    50       90   M          0
# 1  101    43       30   F          1
# 2  102    33       20   F          2
# 3  105    76       50   M          3
# 4  107    98       30   M          4

# %%
#交集
pd.merge(df1, df2, on = 'id')
# Out:
#     id   city  birth_year     name  math  english sex  index_num
# 0  100  Tokyo        1990  Hiroshi    50       90   M          0
# 1  101  Osaka        1989    Akiko    43       30   F          1
# 2  102  Kyoto        1992     Yuki    33       20   F          2

# %%
#聯集
pd.merge(df1, df2, how = 'outer')
# Out:
#       id      city  birth_year     name  math  english  sex  index_num
# 0    100     Tokyo      1990.0  Hiroshi  50.0     90.0    M        0.0
# 1    101     Osaka      1989.0    Akiko  43.0     30.0    F        1.0
# 2    102     Kyoto      1992.0     Yuki  33.0     20.0    F        2.0
# 3    103  Hokkaido      1997.0   Satoru   NaN      NaN  NaN        NaN
# 4    104     Tokyo      1982.0   Steeve   NaN      NaN  NaN        NaN
# 5    106     Tokyo      1991.0   Mituru   NaN      NaN  NaN        NaN
# 6    108     Osaka      1988.0      Aoi   NaN      NaN  NaN        NaN
# 7    110     Kyoto      1990.0    Tarou   NaN      NaN  NaN        NaN
# 8    111  Hokkaido      1995.0   Suguru   NaN      NaN  NaN        NaN
# 9    113     Tokyo      1981.0   Mitsuo   NaN      NaN  NaN        NaN
# 10   105       NaN         NaN      NaN  76.0     50.0    M        3.0
# 11   107       NaN         NaN      NaN  98.0     30.0    M        4.0

# %%
# 左索引連右index_num
pd.merge(df1, df2, left_index = True, right_on = 'index_num')
# Out:
#   id_x      city  birth_year     name id_y  math  english sex  index_num
# 0  100     Tokyo        1990  Hiroshi  100    50       90   M          0
# 1  101     Osaka        1989    Akiko  101    43       30   F          1
# 2  102     Kyoto        1992     Yuki  102    33       20   F          2
# 3  103  Hokkaido        1997   Satoru  105    76       50   M          3
# 4  104     Tokyo        1982   Steeve  107    98       30   M          4

# %%
# left join
pd.merge(df1, df2, how = 'left')
# Out:
#      id      city  birth_year     name  math  english  sex  index_num
# 0   100     Tokyo        1990  Hiroshi  50.0     90.0    M        0.0
# 1   101     Osaka        1989    Akiko  43.0     30.0    F        1.0
# 2   102     Kyoto        1992     Yuki  33.0     20.0    F        2.0
# 3   103  Hokkaido        1997   Satoru   NaN      NaN  NaN        NaN
# 4   104     Tokyo        1982   Steeve   NaN      NaN  NaN        NaN
# 5   106     Tokyo        1991   Mituru   NaN      NaN  NaN        NaN
# 6   108     Osaka        1988      Aoi   NaN      NaN  NaN        NaN
# 7   110     Kyoto        1990    Tarou   NaN      NaN  NaN        NaN
# 8   111  Hokkaido        1995   Suguru   NaN      NaN  NaN        NaN
# 9   113     Tokyo        1981   Mitsuo   NaN      NaN  NaN        NaN

# %%
# Union
data3 = {
    'id': ['117', '118', '119', '120', '125'],
    'city': ['Chiba', 'Kanagawa', 'Tokyo', 'Fukuoka', 'Okinawa'],
    'birth_year': [1990, 1989, 1992, 1997, 1982],
    'name': ['Suguru', 'Kouichi', 'Satochi', 'Yukie', 'Akari']
}
df3 = DataFrame(data3)
df3
# Out:
#     id      city  birth_year     name
# 0  117     Chiba        1990   Suguru
# 1  118  Kanagawa        1989  Kouichi
# 2  119     Tokyo        1992  Satochi
# 3  120   Fukuoka        1997    Yukie
# 4  125   Okinawa        1982    Akari

# %%
concat_data = pd.concat([df1,df3])
concat_data
# Out:
#      id      city  birth_year     name
# 0   100     Tokyo        1990  Hiroshi
# 1   101     Osaka        1989    Akiko
# 2   102     Kyoto        1992     Yuki
# 3   103  Hokkaido        1997   Satoru
# 4   104     Tokyo        1982   Steeve
# 5   106     Tokyo        1991   Mituru
# 6   108     Osaka        1988      Aoi
# 7   110     Kyoto        1990    Tarou
# 8   111  Hokkaido        1995   Suguru
# 9   113     Tokyo        1981   Mitsuo
# 0   117     Chiba        1990   Suguru
# 1   118  Kanagawa        1989  Kouichi
# 2   119     Tokyo        1992  Satochi
# 3   120   Fukuoka        1997    Yukie
# 4   125   Okinawa        1982    Akari

# %%
#6-4
data4 = {
    'ID':['0','1','2','3','4','6','8','11','12','13'],
    'city':['Tokyo','Osaka','Kyoto','Hokkaido','Tokyo','Tokyo','Osaka','Kyoto','Hokkaido','Tokyo'],
    'birth_year':[1990,1989,1992,1997,1982,1991,1988,1990,1995,1981],
    'name':['Hiroshi','Akiko','Yuki','Satoru','Steeve','Mituru','Aoi','Tarou','Suguru','Mitsuo']
}
df4 = DataFrame(data4)
df4
# Out:
#    ID      city  birth_year     name
# 0   0     Tokyo        1990  Hiroshi
# 1   1     Osaka        1989    Akiko
# 2   2     Kyoto        1992     Yuki
# 3   3  Hokkaido        1997   Satoru
# 4   4     Tokyo        1982   Steeve
# 5   6     Tokyo        1991   Mituru
# 6   8     Osaka        1988      Aoi
# 7  11     Kyoto        1990    Tarou
# 8  12  Hokkaido        1995   Suguru
# 9  13     Tokyo        1981   Mitsuo

# %%
data5 = {
    'ID':['0','1','3','6','8'],
    'math':[20,30,50,70,90],
    'English':[30,50,50,70,20],
    'sex':['M','F','F','M','M'],
    'index_num':[0,1,2,3,4]
}
df5 = DataFrame(data5)
df5
# Out:
#   ID  math  English sex  index_num
# 0  0    20       30   M          0
# 1  1    30       50   F          1
# 2  3    50       50   F          2
# 3  6    70       70   M          3
# 4  8    90       20   M          4

# %%
pd.merge(df4, df5, on = 'ID')
# Out:
#   ID      city  birth_year     name  math  English sex  index_num
# 0  0     Tokyo        1990  Hiroshi    20       30   M          0
# 1  1     Osaka        1989    Akiko    30       50   F          1
# 2  3  Hokkaido        1997   Satoru    50       50   F          2
# 3  6     Tokyo        1991   Mituru    70       70   M          3
# 4  8     Osaka        1988      Aoi    90       20   M          4

# %%
#6-5
pd.merge(df1, df2, how = 'outer')
# Out:
#       id      city  birth_year     name  math  english  sex  index_num
# 0    100     Tokyo      1990.0  Hiroshi  50.0     90.0    M        0.0
# 1    101     Osaka      1989.0    Akiko  43.0     30.0    F        1.0
# 2    102     Kyoto      1992.0     Yuki  33.0     20.0    F        2.0
# 3    103  Hokkaido      1997.0   Satoru   NaN      NaN  NaN        NaN
# 4    104     Tokyo      1982.0   Steeve   NaN      NaN  NaN        NaN
# 5    106     Tokyo      1991.0   Mituru   NaN      NaN  NaN        NaN
# 6    108     Osaka      1988.0      Aoi   NaN      NaN  NaN        NaN
# 7    110     Kyoto      1990.0    Tarou   NaN      NaN  NaN        NaN
# 8    111  Hokkaido      1995.0   Suguru   NaN      NaN  NaN        NaN
# 9    113     Tokyo      1981.0   Mitsuo   NaN      NaN  NaN        NaN
# 10   105       NaN         NaN      NaN  76.0     50.0    M        3.0
# 11   107       NaN         NaN      NaN  98.0     30.0    M        4.0

# %%
#6-6
data6 = {
    'ID':['70','80','90','120','150'],
    'city':['Chiba','Kanagawa','Tokyo','Fukuoka','Okinawa'],
    'birth_year':[1980,1999,1995,1994,1994],
    'name':['Suguru','Kouichi','Satochi','Yukie','Akari']
}
df6 = DataFrame(data6)
df6
# Out:
#     ID      city  birth_year     name
# 0   70     Chiba        1980   Suguru
# 1   80  Kanagawa        1999  Kouichi
# 2   90     Tokyo        1995  Satochi
# 3  120   Fukuoka        1994    Yukie
# 4  150   Okinawa        1994    Akari

# %%
pd.concat([df4,df6])
# Out:
#     ID      city  birth_year     name
# 0    0     Tokyo        1990  Hiroshi
# 1    1     Osaka        1989    Akiko
# 2    2     Kyoto        1992     Yuki
# 3    3  Hokkaido        1997   Satoru
# 4    4     Tokyo        1982   Steeve
# 5    6     Tokyo        1991   Mituru
# 6    8     Osaka        1988      Aoi
# 7   11     Kyoto        1990    Tarou
# 8   12  Hokkaido        1995   Suguru
# 9   13     Tokyo        1981   Mitsuo
# 0   70     Chiba        1980   Suguru
# 1   80  Kanagawa        1999  Kouichi
# 2   90     Tokyo        1995  Satochi
# 3  120   Fukuoka        1994    Yukie
# 4  150   Okinawa        1994    Akari

# %% [markdown]
# ## 資料操作與變換

# %%
# 行變成列
hier_df.stack()
# Out:
# city             Osaka  Tokyo
# key1 key2 color
# a    1    Blue       0    NaN
#           Red        2    1.0
#      2    Blue       3    NaN
#           Red        5    4.0
# b    2    Blue       6    NaN
#           Red        8    7.0

# %%
# 列變成行
hier_df.stack().unstack()
# Out:
# city      Osaka     Tokyo
# color      Blue Red  Blue  Red
# key1 key2
# a    1        0   2   NaN  1.0
#      2        3   5   NaN  4.0
# b    2        6   8   NaN  7.0

# %%
# 資料去重複
dupli_data = DataFrame({
        'col1': [1, 1, 2, 3, 4, 4, 6, 6],
        'col2': ['a', 'b', 'b', 'b', 'c', 'c', 'b', 'b']
})
dupli_data
# Out:
#    col1 col2
# 0     1    a
# 1     1    b
# 2     2    b
# 3     3    b
# 4     4    c
# 5     4    c
# 6     6    b
# 7     6    b

# %%
#　重複判定
dupli_data.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6    False
# 7     True
# dtype: bool

# %%
# 刪除重複
dupli_data.drop_duplicates()
# Out:
#    col1 col2
# 0     1    a
# 1     1    b
# 2     2    b
# 3     3    b
# 4     4    c
# 6     6    b

# %%
# mapping
city_map ={
    'Tokyo': 'Kanto',
    'Hokkaido': 'Hokkaido',
    'Osaka': 'Kansai',
    'Kyoto':'Kansai'
}
city_map
# Out:
# {'Tokyo': 'Kanto',
#  'Hokkaido': 'Hokkaido',
#  'Osaka': 'Kansai',
#  'Kyoto': 'Kansai'}

# %%
df1['region'] = df1['city'].map(city_map)
df1
# Out:
#      id      city  birth_year     name    region
# 0   100     Tokyo        1990  Hiroshi     Kanto
# 1   101     Osaka        1989    Akiko    Kansai
# 2   102     Kyoto        1992     Yuki    Kansai
# 3   103  Hokkaido        1997   Satoru  Hokkaido
# 4   104     Tokyo        1982   Steeve     Kanto
# 5   106     Tokyo        1991   Mituru     Kanto
# 6   108     Osaka        1988      Aoi    Kansai
# 7   110     Kyoto        1990    Tarou    Kansai
# 8   111  Hokkaido        1995   Suguru  Hokkaido
# 9   113     Tokyo        1981   Mitsuo     Kanto

# %%
#lambda
df1['up_two_num'] = df1['birth_year'].map(lambda x: str(x)[0:3])
df1
# Out:
#      id      city  birth_year     name    region up_two_num
# 0   100     Tokyo        1990  Hiroshi     Kanto        199
# 1   101     Osaka        1989    Akiko    Kansai        198
# 2   102     Kyoto        1992     Yuki    Kansai        199
# 3   103  Hokkaido        1997   Satoru  Hokkaido        199
# 4   104     Tokyo        1982   Steeve     Kanto        198
# 5   106     Tokyo        1991   Mituru     Kanto        199
# 6   108     Osaka        1988      Aoi    Kansai        198
# 7   110     Kyoto        1990    Tarou    Kansai        199
# 8   111  Hokkaido        1995   Suguru  Hokkaido        199
# 9   113     Tokyo        1981   Mitsuo     Kanto        198

# %%
#binning
birth_year_bins = [1980, 1985, 1990, 1995, 2000]

birth_year_cut_data = pd.cut(df1.birth_year, birth_year_bins)
birth_year_cut_data
# Out:
# 0    (1985, 1990]
# 1    (1985, 1990]
# 2    (1990, 1995]
# 3    (1995, 2000]
# 4    (1980, 1985]
# 5    (1990, 1995]
# 6    (1985, 1990]
# 7    (1985, 1990]
# 8    (1990, 1995]
# 9    (1980, 1985]
# Name: birth_year, dtype: category
# Categories (4, interval[int64]): [(1980, 1985] < (1985, 1990] < (1990, 1995] < (1995, 2000]]

# %%
pd.value_counts(birth_year_cut_data)
# Out:
# (1985, 1990]    4
# (1990, 1995]    3
# (1980, 1985]    2
# (1995, 2000]    1
# Name: birth_year, dtype: int64

# %%
# label
group_names = ['early1980s', 'late1980s', 'early1990s', 'late1990s']
birth_year_cut_data = pd.cut(df1.birth_year, birth_year_bins, labels = group_names)
pd.value_counts(birth_year_cut_data)
# Out:
# late1980s     4
# early1990s    3
# early1980s    2
# late1990s     1
# Name: birth_year, dtype: int64

# %%
pd.cut(df1.birth_year, 2)
# Out:
# 0      (1989.0, 1997.0]
# 1    (1980.984, 1989.0]
# 2      (1989.0, 1997.0]
# 3      (1989.0, 1997.0]
# 4    (1980.984, 1989.0]
# 5      (1989.0, 1997.0]
# 6    (1980.984, 1989.0]
# 7      (1989.0, 1997.0]
# 8      (1989.0, 1997.0]
# 9    (1980.984, 1989.0]
# Name: birth_year, dtype: category
# Categories (2, interval[float64]): [(1980.984, 1989.0] < (1989.0, 1997.0]]

# %%
pd.value_counts(pd.qcut(df1.birth_year, 2))
# Out:
# (1980.999, 1990.0]    6
# (1990.0, 1997.0]      4
# Name: birth_year, dtype: int64

# %%
#6-7
student = pd.read_csv('student-mat.csv',sep =';')

# %%
student.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
student['age_d'] = student['age'].map(lambda x: 2*x)

# %%
student['age_d'].head()
# Out:
# 0    36
# 1    34
# 2    30
# 3    30
# 4    32
# Name: age_d, dtype: int64

# %%
#6-8
absences_bins = [0,1,5,100]
student_ab_cut_data = pd.cut(student.absences,absences_bins,right=False)
pd.value_counts(student_ab_cut_data)
# Out:
# [5, 100)    151
# [1, 5)      129
# [0, 1)      115
# Name: absences, dtype: int64

# %%
#6-9
studen_ab_qcut_data = pd.qcut(student.absences,3)
pd.value_counts(studen_ab_qcut_data)
# Out:
# (-0.001, 2.0]    183
# (6.0, 75.0]      115
# (2.0, 6.0]        97
# Name: absences, dtype: int64

# %% [markdown]
# ## 資料群組運算

# %%
df1
# Out:
#      id      city  birth_year     name    region up_two_num
# 0   100     Tokyo        1990  Hiroshi     Kanto        199
# 1   101     Osaka        1989    Akiko    Kansai        198
# 2   102     Kyoto        1992     Yuki    Kansai        199
# 3   103  Hokkaido        1997   Satoru  Hokkaido        199
# 4   104     Tokyo        1982   Steeve     Kanto        198
# 5   106     Tokyo        1991   Mituru     Kanto        199
# 6   108     Osaka        1988      Aoi    Kansai        198
# 7   110     Kyoto        1990    Tarou    Kansai        199
# 8   111  Hokkaido        1995   Suguru  Hokkaido        199
# 9   113     Tokyo        1981   Mitsuo     Kanto        198

# %%
df1.groupby('city').size()
# Out:
# city
# Hokkaido    2
# Kyoto       2
# Osaka       2
# Tokyo       4
# dtype: int64

# %%
df1.groupby('city')['birth_year'].mean()
# Out:
# city
# Hokkaido    1996.0
# Kyoto       1991.0
# Osaka       1988.5
# Tokyo       1986.0
# Name: birth_year, dtype: float64

# %%
df1.groupby(['region', 'city'])['birth_year'].mean()
# Out:
# region    city
# Hokkaido  Hokkaido    1996.0
# Kansai    Kyoto       1991.0
#           Osaka       1988.5
# Kanto     Tokyo       1986.0
# Name: birth_year, dtype: float64

# %%
#迭代器
for group, subdf in df1.groupby('region'):
    print('==========================================================')
    print('Region Name:{0}'.format(group))
    print(subdf)
# Out:
# ==========================================================
# Region Name:Hokkaido
#     id      city  birth_year    name    region up_two_num
# 3  103  Hokkaido        1997  Satoru  Hokkaido        199
# 8  111  Hokkaido        1995  Suguru  Hokkaido        199
# ==========================================================
# Region Name:Kansai
#     id   city  birth_year   name  region up_two_num
# 1  101  Osaka        1989  Akiko  Kansai        198
# 2  102  Kyoto        1992   Yuki  Kansai        199
# 6  108  Osaka        1988    Aoi  Kansai        198
# 7  110  Kyoto        1990  Tarou  Kansai        199
# ==========================================================
# Region Name:Kanto
#      id   city  birth_year     name region up_two_num
# 0   100  Tokyo        1990  Hiroshi  Kanto        199
# 4   104  Tokyo        1982   Steeve  Kanto        198
# 5   106  Tokyo        1991   Mituru  Kanto        199
# 9   113  Tokyo        1981   Mitsuo  Kanto        198

# %%
# agg
functions = ['count','mean','max','min']
grouped_student_data1 = student.groupby(['sex','address'])
grouped_student_data1['age','G1'].agg(functions)
# Out:
# /Users/alisa/.local/share/virtualenvs/ds_samplefiles-_NgilYim/lib/python3.6/site-packages/ipykernel_launcher.py:4: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   after removing the cwd from sys.path.
#               age                       G1
#             count       mean max min count       mean max min
# sex address
# F   R          44  16.977273  19  15    44  10.295455  19   6
#     U         164  16.664634  20  15   164  10.707317  18   4
# M   R          44  17.113636  21  15    44  10.659091  18   3
#     U         143  16.517483  22  15   143  11.405594  19   5

# %%
#6-10
student.groupby('school')['G1'].mean()
# Out:
# school
# GP    10.939828
# MS    10.673913
# Name: G1, dtype: float64

# %%
#6-11
student.groupby(['school', 'sex'])['G1','G2','G3'].mean()
# Out:
# /Users/alisa/.local/share/virtualenvs/ds_samplefiles-_NgilYim/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#                    G1         G2         G3
# school sex
# GP     F    10.579235  10.398907   9.972678
#        M    11.337349  11.204819  11.060241
# MS     F    10.920000  10.320000   9.920000
#        M    10.380952  10.047619   9.761905

# %%
#6-12
functions = ['count','mean','max','min']
grouped_student_data1 = student.groupby(['school','sex'])
grouped_student_data1['G1','G2','G3'].agg(functions)
# Out:
# /Users/alisa/.local/share/virtualenvs/ds_samplefiles-_NgilYim/lib/python3.6/site-packages/ipykernel_launcher.py:4: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   after removing the cwd from sys.path.
#               G1                       G2                       G3             \
#            count       mean max min count       mean max min count       mean
# school sex
# GP     F     183  10.579235  18   4   183  10.398907  18   0   183   9.972678
#        M     166  11.337349  19   3   166  11.204819  19   0   166  11.060241
# MS     F      25  10.920000  19   6    25  10.320000  18   5    25   9.920000
#        M      21  10.380952  15   6    21  10.047619  16   5    21   9.761905
#
#
#            max min
# school sex
# GP     F    19   0
#        M    20   0
# MS     F    19   0
#        M    16   0

# %% [markdown]
# ## 遺漏值與異常值處理

# %%
from numpy import nan as NA
df = pd.DataFrame(np.random.rand(10, 4))
df.iloc[1,0] = NA
df.iloc[2:3,2] = NA
df.iloc[5:,3] = NA

# %%
df
# Out:
#           0         1         2         3
# 0  0.352912  0.403749  0.323026  0.576396
# 1       NaN  0.760099  0.514301  0.479090
# 2  0.884017  0.375859       NaN  0.355023
# 3  0.982381  0.960130  0.335410  0.241237
# 4  0.515911  0.820713  0.407489  0.549207
# 5  0.703743  0.962435  0.082548       NaN
# 6  0.775284  0.609181  0.214025       NaN
# 7  0.122300  0.987193  0.569118       NaN
# 8  0.892584  0.644298  0.569243       NaN
# 9  0.704270  0.161819  0.935483       NaN

# %%
#全部刪除
df.dropna()
# Out:
#           0         1         2         3
# 0  0.352912  0.403749  0.323026  0.576396
# 3  0.982381  0.960130  0.335410  0.241237
# 4  0.515911  0.820713  0.407489  0.549207

# %%
# 忽略遺漏值
df[[0,1]].dropna()
# Out:
#           0         1
# 0  0.352912  0.403749
# 2  0.884017  0.375859
# 3  0.982381  0.960130
# 4  0.515911  0.820713
# 5  0.703743  0.962435
# 6  0.775284  0.609181
# 7  0.122300  0.987193
# 8  0.892584  0.644298
# 9  0.704270  0.161819

# %%
# 補0
df1.fillna(0)
# Out:
#      id      city  birth_year     name    region up_two_num
# 0   100     Tokyo        1990  Hiroshi     Kanto        199
# 1   101     Osaka        1989    Akiko    Kansai        198
# 2   102     Kyoto        1992     Yuki    Kansai        199
# 3   103  Hokkaido        1997   Satoru  Hokkaido        199
# 4   104     Tokyo        1982   Steeve     Kanto        198
# 5   106     Tokyo        1991   Mituru     Kanto        199
# 6   108     Osaka        1988      Aoi    Kansai        198
# 7   110     Kyoto        1990    Tarou    Kansai        199
# 8   111  Hokkaido        1995   Suguru  Hokkaido        199
# 9   113     Tokyo        1981   Mitsuo     Kanto        198

# %%
df.iloc[1,0] = NA

# %%
# 用前面的值補
df.fillna(method = 'ffill')
# Out:
#           0         1         2         3
# 0  0.352912  0.403749  0.323026  0.576396
# 1  0.352912  0.760099  0.514301  0.479090
# 2  0.884017  0.375859  0.514301  0.355023
# 3  0.982381  0.960130  0.335410  0.241237
# 4  0.515911  0.820713  0.407489  0.549207
# 5  0.703743  0.962435  0.082548  0.549207
# 6  0.775284  0.609181  0.214025  0.549207
# 7  0.122300  0.987193  0.569118  0.549207
# 8  0.892584  0.644298  0.569243  0.549207
# 9  0.704270  0.161819  0.935483  0.549207

# %%
#6-13
df2 = pd.DataFrame(np.random.rand(15,6))


df2.iloc[2,0] = NA
df2.iloc[5:8,2] = NA
df2.iloc[7:9,3] = NA
df2.iloc[10,5] = NA


df2
# Out:
#            0         1         2         3         4         5
# 0   0.576374  0.668027  0.827249  0.083923  0.339355  0.797632
# 1   0.696286  0.754065  0.885602  0.940419  0.592270  0.896823
# 2        NaN  0.487904  0.033717  0.214159  0.348258  0.923437
# 3   0.477823  0.740758  0.834722  0.446814  0.491668  0.138485
# 4   0.630097  0.437050  0.736764  0.952513  0.682957  0.038810
# 5   0.877335  0.527259       NaN  0.301574  0.135107  0.030347
# 6   0.981109  0.147914       NaN  0.078328  0.409733  0.954465
# 7   0.235098  0.359893       NaN       NaN  0.519341  0.974184
# 8   0.213055  0.987412  0.957167       NaN  0.275236  0.871166
# 9   0.115259  0.529808  0.797707  0.158644  0.709923  0.366718
# 10  0.767341  0.815328  0.978676  0.014980  0.072207       NaN
# 11  0.032509  0.799086  0.370315  0.131882  0.493014  0.092300
# 12  0.085114  0.846813  0.868754  0.610987  0.986252  0.805822
# 13  0.403932  0.491519  0.100943  0.729946  0.466308  0.644510
# 14  0.074289  0.820750  0.105367  0.461938  0.295517  0.457013

# %%
df2.dropna()
# Out:
#            0         1         2         3         4         5
# 0   0.576374  0.668027  0.827249  0.083923  0.339355  0.797632
# 1   0.696286  0.754065  0.885602  0.940419  0.592270  0.896823
# 3   0.477823  0.740758  0.834722  0.446814  0.491668  0.138485
# 4   0.630097  0.437050  0.736764  0.952513  0.682957  0.038810
# 9   0.115259  0.529808  0.797707  0.158644  0.709923  0.366718
# 11  0.032509  0.799086  0.370315  0.131882  0.493014  0.092300
# 12  0.085114  0.846813  0.868754  0.610987  0.986252  0.805822
# 13  0.403932  0.491519  0.100943  0.729946  0.466308  0.644510
# 14  0.074289  0.820750  0.105367  0.461938  0.295517  0.457013

# %%
#6-14
df2.fillna(0)
# Out:
#            0         1         2         3         4         5
# 0   0.576374  0.668027  0.827249  0.083923  0.339355  0.797632
# 1   0.696286  0.754065  0.885602  0.940419  0.592270  0.896823
# 2   0.000000  0.487904  0.033717  0.214159  0.348258  0.923437
# 3   0.477823  0.740758  0.834722  0.446814  0.491668  0.138485
# 4   0.630097  0.437050  0.736764  0.952513  0.682957  0.038810
# 5   0.877335  0.527259  0.000000  0.301574  0.135107  0.030347
# 6   0.981109  0.147914  0.000000  0.078328  0.409733  0.954465
# 7   0.235098  0.359893  0.000000  0.000000  0.519341  0.974184
# 8   0.213055  0.987412  0.957167  0.000000  0.275236  0.871166
# 9   0.115259  0.529808  0.797707  0.158644  0.709923  0.366718
# 10  0.767341  0.815328  0.978676  0.014980  0.072207  0.000000
# 11  0.032509  0.799086  0.370315  0.131882  0.493014  0.092300
# 12  0.085114  0.846813  0.868754  0.610987  0.986252  0.805822
# 13  0.403932  0.491519  0.100943  0.729946  0.466308  0.644510
# 14  0.074289  0.820750  0.105367  0.461938  0.295517  0.457013

# %%
#6-15
df2.fillna(df2.mean())
# Out:
#            0         1         2         3         4         5
# 0   0.576374  0.668027  0.827249  0.083923  0.339355  0.797632
# 1   0.696286  0.754065  0.885602  0.940419  0.592270  0.896823
# 2   0.440401  0.487904  0.033717  0.214159  0.348258  0.923437
# 3   0.477823  0.740758  0.834722  0.446814  0.491668  0.138485
# 4   0.630097  0.437050  0.736764  0.952513  0.682957  0.038810
# 5   0.877335  0.527259  0.624749  0.301574  0.135107  0.030347
# 6   0.981109  0.147914  0.624749  0.078328  0.409733  0.954465
# 7   0.235098  0.359893  0.624749  0.394316  0.519341  0.974184
# 8   0.213055  0.987412  0.957167  0.394316  0.275236  0.871166
# 9   0.115259  0.529808  0.797707  0.158644  0.709923  0.366718
# 10  0.767341  0.815328  0.978676  0.014980  0.072207  0.570837
# 11  0.032509  0.799086  0.370315  0.131882  0.493014  0.092300
# 12  0.085114  0.846813  0.868754  0.610987  0.986252  0.805822
# 13  0.403932  0.491519  0.100943  0.729946  0.466308  0.644510
# 14  0.074289  0.820750  0.105367  0.461938  0.295517  0.457013

# %% [markdown]
# ## 時間序列資料處理

# %%
import pandas_datareader.data as pdr

# %%
start_date = '2001/1/2'
end_date = '2016/12/30'

fx_jpusdata = pdr.DataReader('DEXJPUS', 'fred', start_date, end_date)

# %%
fx_jpusdata.head()
# Out:
#             DEXJPUS
# DATE
# 2001-01-02   114.73
# 2001-01-03   114.26
# 2001-01-04   115.47
# 2001-01-05   116.19
# 2001-01-08   115.97

# %%
fx_jpusdata['2016-04']
# Out:
#             DEXJPUS
# DATE
# 2016-04-01   112.06
# 2016-04-04   111.18
# 2016-04-05   110.26
# 2016-04-06   109.63
# 2016-04-07   107.98
# 2016-04-08   108.36
# 2016-04-11   107.96
# 2016-04-12   108.54
# 2016-04-13   109.21
# 2016-04-14   109.20
# 2016-04-15   108.76
# 2016-04-18   108.85
# 2016-04-19   109.16
# 2016-04-20   109.51
# 2016-04-21   109.41
# 2016-04-22   111.50
# 2016-04-25   111.08
# 2016-04-26   111.23
# 2016-04-27   111.26
# 2016-04-28   108.55
# 2016-04-29   106.90

# %%
#月底資料
fx_jpusdata.resample('M').last().head()
# Out:
#             DEXJPUS
# DATE
# 2001-01-31   116.39
# 2001-02-28   117.28
# 2001-03-31   125.54
# 2001-04-30   123.57
# 2001-05-31   118.88

# %%
# 資料偏移
fx_jpusdata.shift(1).head()
# Out:
#             DEXJPUS
# DATE
# 2001-01-02      NaN
# 2001-01-03   114.73
# 2001-01-04   114.26
# 2001-01-05   115.47
# 2001-01-08   116.19

# %%
fx_jpusdata_ratio = fx_jpusdata / fx_jpusdata.shift(1)
fx_jpusdata_ratio.head()
# Out:
#              DEXJPUS
# DATE
# 2001-01-02       NaN
# 2001-01-03  0.995903
# 2001-01-04  1.010590
# 2001-01-05  1.006235
# 2001-01-08  0.998107
